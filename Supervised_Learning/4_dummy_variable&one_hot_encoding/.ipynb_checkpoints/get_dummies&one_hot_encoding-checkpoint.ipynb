# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  2600  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9      robbinsville  2600  575000
# 10     robbinsville  2900  600000
# 11     robbinsville  3100  620000
# 12     robbinsville  3600  695000

# %%
dummies = pd.get_dummies(df.town)
dummies
# Out:
#     monroe township  robbinsville  west windsor
# 0                 1             0             0
# 1                 1             0             0
# 2                 1             0             0
# 3                 1             0             0
# 4                 1             0             0
# 5                 0             0             1
# 6                 0             0             1
# 7                 0             0             1
# 8                 0             0             1
# 9                 0             1             0
# 10                0             1             0
# 11                0             1             0
# 12                0             1             0

# %%
df_dummies = pd.concat([df,dummies],axis='columns')
df_dummies
# Out:
#                town  area   price  monroe township  robbinsville  west windsor
# 0   monroe township  2600  550000                1             0             0
# 1   monroe township  3000  565000                1             0             0
# 2   monroe township  3200  610000                1             0             0
# 3   monroe township  3600  680000                1             0             0
# 4   monroe township  2600  725000                1             0             0
# 5      west windsor  2600  585000                0             0             1
# 6      west windsor  2800  615000                0             0             1
# 7      west windsor  3300  650000                0             0             1
# 8      west windsor  3600  710000                0             0             1
# 9      robbinsville  2600  575000                0             1             0
# 10     robbinsville  2900  600000                0             1             0
# ...

# %%
df_dummies.drop(['west windsor'],axis='columns',inplace=True)
df_dummies
# Out:
#     area   price  monroe township  robbinsville
# 0   2600  550000                1             0
# 1   3000  565000                1             0
# 2   3200  610000                1             0
# 3   3600  680000                1             0
# 4   2600  725000                1             0
# 5   2600  585000                0             0
# 6   2800  615000                0             0
# 7   3300  650000                0             0
# 8   3600  710000                0             0
# 9   2600  575000                0             1
# 10  2900  600000                0             1
# 11  3100  620000                0             1
# 12  3600  695000                0             1

# %%
X = df_dummies.drop('price',axis='columns')
X
# Out:
#     area  monroe township  robbinsville
# 0   2600                1             0
# 1   3000                1             0
# 2   3200                1             0
# 3   3600                1             0
# 4   2600                1             0
# 5   2600                0             0
# 6   2800                0             0
# 7   3300                0             0
# 8   3600                0             0
# 9   2600                0             1
# 10  2900                0             1
# 11  3100                0             1
# 12  3600                0             1

# %%
y = df_dummies.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.predict([[3400,0,0]])
# Out:
# array([667090.54593875])

# %%
model.predict([[2800,0,1]])
# Out:
# array([601661.11850866])

# %%
model.score(X,y)
# Out:
# 0.3449209722493761

# %%
import pickle

# %%
with open('model_pickle','wb') as file:
    pickle.dump(model,file)

# %%
with open('model_pickle','rb') as a:
    get_dummies_model = pickle.load(a)

# %%
get_dummies_model.predict([[3400,0,0]])
# Out:
# array([667090.54593875])

# %% [markdown]
# # one_hot_encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle= df

# %%
dfle.town  = le.fit_transform(dfle.town)
dfle
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  2600  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
X = dfle[['town','area']].values #Values give 2D array
X
# Out:
# array([[   0, 2600],
#        [   0, 3000],
#        [   0, 3200],
#        [   0, 3600],
#        [   0, 2600],
#        [   2, 2600],
#        [   2, 2800],
#        [   2, 3300],
#        [   2, 3600],
#        [   1, 2600],
#        [   1, 2900],
#        [   1, 3100],
#        [   1, 3600]], dtype=int64)

# %%
y = dfle.price.values
y
# Out:
# array([550000, 565000, 610000, 680000, 725000, 585000, 615000, 650000,
#        710000, 575000, 600000, 620000, 695000], dtype=int64)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(categorical_features=[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-7f64b3ea45ce> in <module>
#       1 from sklearn.preprocessing import OneHotEncoder
# ----> 2 ohe = OneHotEncoder(categorical_features=[0])
#
# TypeError: __init__() got an unexpected keyword argument 'categorical_features'

# %%
X = ohe.fit_transform(X).toarray()
X
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-ef8eb030aadb> in <module>
# ----> 1 X = ohe.fit_transform(X).toarray()
#       2 X
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     370         """
#     371         self._validate_keywords()
# --> 372         return super().fit_transform(X, y)
#     373
#     374     def transform(self, X):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# ...
